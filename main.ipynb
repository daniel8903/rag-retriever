# %%
# create env
# python3 -m venv prompt-gen-env
# source prompt-gen-env/bin/activate

# !pip install langchain
# !pip install langchain-community
# !pip install langchain-huggingface
# !pip install faiss-cpu  # or faiss-gpu if you have a compatible GPU
# !pip install pandas
# !pip install panel jupyter_bokeh
# Out:
# Requirement already satisfied: langchain in ./prompt-gen-env/lib/python3.10/site-packages (0.3.24)
# Requirement already satisfied: requests<3,>=2 in ./prompt-gen-env/lib/python3.10/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.55 in ./prompt-gen-env/lib/python3.10/site-packages (from langchain) (0.3.56)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in ./prompt-gen-env/lib/python3.10/site-packages (from langchain) (0.3.8)
# Requirement already satisfied: PyYAML>=5.3 in ./prompt-gen-env/lib/python3.10/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in ./prompt-gen-env/lib/python3.10/site-packages (from langchain) (0.3.38)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in ./prompt-gen-env/lib/python3.10/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in ./prompt-gen-env/lib/python3.10/site-packages (from langchain) (2.0.40)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in ./prompt-gen-env/lib/python3.10/site-packages (from langchain) (2.11.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in ./prompt-gen-env/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.55->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./prompt-gen-env/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.55->langchain) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in ./prompt-gen-env/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.55->langchain) (4.13.2)
# Requirement already satisfied: packaging<25,>=23.2 in ./prompt-gen-env/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.55->langchain) (24.2)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in ./prompt-gen-env/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./prompt-gen-env/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in ./prompt-gen-env/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.16)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in ./prompt-gen-env/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: pydantic-core==2.33.1 in ./prompt-gen-env/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in ./prompt-gen-env/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./prompt-gen-env/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./prompt-gen-env/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2025.4.26)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./prompt-gen-env/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./prompt-gen-env/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in ./prompt-gen-env/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: greenlet>=1 in ./prompt-gen-env/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.1)
# Requirement already satisfied: httpcore==1.* in ./prompt-gen-env/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: anyio in ./prompt-gen-env/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.9.0)
# Requirement already satisfied: h11>=0.16 in ./prompt-gen-env/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./prompt-gen-env/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.55->langchain) (3.0.0)
# Requirement already satisfied: sniffio>=1.1 in ./prompt-gen-env/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./prompt-gen-env/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.2.2)
# Requirement already satisfied: langchain-community in ./prompt-gen-env/lib/python3.10/site-packages (0.3.23)
# Requirement already satisfied: PyYAML>=5.3 in ./prompt-gen-env/lib/python3.10/site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.56 in ./prompt-gen-env/lib/python3.10/site-packages (from langchain-community) (0.3.56)
# Requirement already satisfied: requests<3,>=2 in ./prompt-gen-env/lib/python3.10/site-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: numpy>=1.26.2 in ./prompt-gen-env/lib/python3.10/site-packages (from langchain-community) (2.2.5)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in ./prompt-gen-env/lib/python3.10/site-packages (from langchain-community) (2.9.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in ./prompt-gen-env/lib/python3.10/site-packages (from langchain-community) (0.3.38)
# Requirement already satisfied: langchain<1.0.0,>=0.3.24 in ./prompt-gen-env/lib/python3.10/site-packages (from langchain-community) (0.3.24)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in ./prompt-gen-env/lib/python3.10/site-packages (from langchain-community) (3.11.18)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in ./prompt-gen-env/lib/python3.10/site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in ./prompt-gen-env/lib/python3.10/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in ./prompt-gen-env/lib/python3.10/site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in ./prompt-gen-env/lib/python3.10/site-packages (from langchain-community) (2.0.40)
# Requirement already satisfied: attrs>=17.3.0 in ./prompt-gen-env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in ./prompt-gen-env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in ./prompt-gen-env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./prompt-gen-env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.4.3)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./prompt-gen-env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./prompt-gen-env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: propcache>=0.2.0 in ./prompt-gen-env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in ./prompt-gen-env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in ./prompt-gen-env/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./prompt-gen-env/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in ./prompt-gen-env/lib/python3.10/site-packages (from langchain<1.0.0,>=0.3.24->langchain-community) (2.11.3)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in ./prompt-gen-env/lib/python3.10/site-packages (from langchain<1.0.0,>=0.3.24->langchain-community) (0.3.8)
# Requirement already satisfied: packaging<25,>=23.2 in ./prompt-gen-env/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.56->langchain-community) (24.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./prompt-gen-env/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.56->langchain-community) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in ./prompt-gen-env/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.56->langchain-community) (4.13.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./prompt-gen-env/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in ./prompt-gen-env/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (3.10.16)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in ./prompt-gen-env/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in ./prompt-gen-env/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in ./prompt-gen-env/lib/python3.10/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.1.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in ./prompt-gen-env/lib/python3.10/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (0.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./prompt-gen-env/lib/python3.10/site-packages (from requests<3,>=2->langchain-community) (2025.4.26)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./prompt-gen-env/lib/python3.10/site-packages (from requests<3,>=2->langchain-community) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./prompt-gen-env/lib/python3.10/site-packages (from requests<3,>=2->langchain-community) (2.4.0)
# Requirement already satisfied: idna<4,>=2.5 in ./prompt-gen-env/lib/python3.10/site-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: greenlet>=1 in ./prompt-gen-env/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.2.1)
# Requirement already satisfied: httpcore==1.* in ./prompt-gen-env/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: anyio in ./prompt-gen-env/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (4.9.0)
# Requirement already satisfied: h11>=0.16 in ./prompt-gen-env/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./prompt-gen-env/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.56->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./prompt-gen-env/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.24->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in ./prompt-gen-env/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.24->langchain-community) (2.33.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./prompt-gen-env/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.1.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./prompt-gen-env/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.2.2)
# Requirement already satisfied: sniffio>=1.1 in ./prompt-gen-env/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.3.1)
# Requirement already satisfied: langchain-huggingface in ./prompt-gen-env/lib/python3.10/site-packages (0.1.2)
# Requirement already satisfied: transformers>=4.39.0 in ./prompt-gen-env/lib/python3.10/site-packages (from langchain-huggingface) (4.51.3)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.15 in ./prompt-gen-env/lib/python3.10/site-packages (from langchain-huggingface) (0.3.56)
# Requirement already satisfied: tokenizers>=0.19.1 in ./prompt-gen-env/lib/python3.10/site-packages (from langchain-huggingface) (0.21.1)
# Requirement already satisfied: huggingface-hub>=0.23.0 in ./prompt-gen-env/lib/python3.10/site-packages (from langchain-huggingface) (0.30.2)
# Requirement already satisfied: sentence-transformers>=2.6.0 in ./prompt-gen-env/lib/python3.10/site-packages (from langchain-huggingface) (4.1.0)
# Requirement already satisfied: tqdm>=4.42.1 in ./prompt-gen-env/lib/python3.10/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in ./prompt-gen-env/lib/python3.10/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./prompt-gen-env/lib/python3.10/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (4.13.2)
# Requirement already satisfied: filelock in ./prompt-gen-env/lib/python3.10/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (3.18.0)
# Requirement already satisfied: pyyaml>=5.1 in ./prompt-gen-env/lib/python3.10/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (6.0.2)
# Requirement already satisfied: requests in ./prompt-gen-env/lib/python3.10/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (2.32.3)
# Requirement already satisfied: packaging>=20.9 in ./prompt-gen-env/lib/python3.10/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (24.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in ./prompt-gen-env/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (2.11.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./prompt-gen-env/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (1.33)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in ./prompt-gen-env/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (9.1.2)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in ./prompt-gen-env/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (0.3.38)
# Requirement already satisfied: Pillow in ./prompt-gen-env/lib/python3.10/site-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (11.2.1)
# Requirement already satisfied: scikit-learn in ./prompt-gen-env/lib/python3.10/site-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (1.6.1)
# Requirement already satisfied: scipy in ./prompt-gen-env/lib/python3.10/site-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (1.15.2)
# Requirement already satisfied: torch>=1.11.0 in ./prompt-gen-env/lib/python3.10/site-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (2.7.0)
# Requirement already satisfied: regex!=2019.12.17 in ./prompt-gen-env/lib/python3.10/site-packages (from transformers>=4.39.0->langchain-huggingface) (2024.11.6)
# Requirement already satisfied: safetensors>=0.4.3 in ./prompt-gen-env/lib/python3.10/site-packages (from transformers>=4.39.0->langchain-huggingface) (0.5.3)
# Requirement already satisfied: numpy>=1.17 in ./prompt-gen-env/lib/python3.10/site-packages (from transformers>=4.39.0->langchain-huggingface) (2.2.5)
# Requirement already satisfied: jsonpointer>=1.9 in ./prompt-gen-env/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./prompt-gen-env/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (0.28.1)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in ./prompt-gen-env/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (0.23.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in ./prompt-gen-env/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in ./prompt-gen-env/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (1.0.0)
# Requirement already satisfied: pydantic-core==2.33.1 in ./prompt-gen-env/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (2.33.1)
# Requirement already satisfied: annotated-types>=0.6.0 in ./prompt-gen-env/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in ./prompt-gen-env/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (0.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./prompt-gen-env/lib/python3.10/site-packages (from requests->huggingface-hub>=0.23.0->langchain-huggingface) (2025.4.26)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./prompt-gen-env/lib/python3.10/site-packages (from requests->huggingface-hub>=0.23.0->langchain-huggingface) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in ./prompt-gen-env/lib/python3.10/site-packages (from requests->huggingface-hub>=0.23.0->langchain-huggingface) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./prompt-gen-env/lib/python3.10/site-packages (from requests->huggingface-hub>=0.23.0->langchain-huggingface) (2.4.0)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in ./prompt-gen-env/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (12.5.4.2)
# Requirement already satisfied: networkx in ./prompt-gen-env/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (3.4.2)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in ./prompt-gen-env/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (11.3.0.4)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in ./prompt-gen-env/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (11.7.1.2)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in ./prompt-gen-env/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (12.6.85)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in ./prompt-gen-env/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (9.5.1.17)
# Requirement already satisfied: jinja2 in ./prompt-gen-env/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (3.1.6)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in ./prompt-gen-env/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (12.6.4.1)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in ./prompt-gen-env/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (10.3.7.77)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in ./prompt-gen-env/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (2.26.2)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in ./prompt-gen-env/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (12.6.77)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in ./prompt-gen-env/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (12.6.77)
# Requirement already satisfied: triton==3.3.0 in ./prompt-gen-env/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (3.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in ./prompt-gen-env/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in ./prompt-gen-env/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (12.6.80)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in ./prompt-gen-env/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (1.11.1.6)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in ./prompt-gen-env/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (0.6.3)
# Requirement already satisfied: sympy>=1.13.3 in ./prompt-gen-env/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (1.14.0)
# Requirement already satisfied: setuptools>=40.8.0 in ./prompt-gen-env/lib/python3.10/site-packages (from triton==3.3.0->torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (59.6.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./prompt-gen-env/lib/python3.10/site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain-huggingface) (3.6.0)
# Requirement already satisfied: joblib>=1.2.0 in ./prompt-gen-env/lib/python3.10/site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain-huggingface) (1.4.2)
# Requirement already satisfied: anyio in ./prompt-gen-env/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (4.9.0)
# Requirement already satisfied: httpcore==1.* in ./prompt-gen-env/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./prompt-gen-env/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (0.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./prompt-gen-env/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./prompt-gen-env/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (3.0.2)
# Requirement already satisfied: sniffio>=1.1 in ./prompt-gen-env/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./prompt-gen-env/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (1.2.2)
# Requirement already satisfied: faiss-cpu in ./prompt-gen-env/lib/python3.10/site-packages (1.11.0)
# Requirement already satisfied: packaging in ./prompt-gen-env/lib/python3.10/site-packages (from faiss-cpu) (24.2)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in ./prompt-gen-env/lib/python3.10/site-packages (from faiss-cpu) (2.2.5)
# Requirement already satisfied: pandas in ./prompt-gen-env/lib/python3.10/site-packages (2.2.3)
# Requirement already satisfied: pytz>=2020.1 in ./prompt-gen-env/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: numpy>=1.22.4 in ./prompt-gen-env/lib/python3.10/site-packages (from pandas) (2.2.5)
# Requirement already satisfied: tzdata>=2022.7 in ./prompt-gen-env/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./prompt-gen-env/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./prompt-gen-env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: panel in ./prompt-gen-env/lib/python3.10/site-packages (1.6.3)
# Requirement already satisfied: jupyter_bokeh in ./prompt-gen-env/lib/python3.10/site-packages (4.0.5)
# Requirement already satisfied: param<3.0,>=2.1.0 in ./prompt-gen-env/lib/python3.10/site-packages (from panel) (2.2.0)
# Requirement already satisfied: packaging in ./prompt-gen-env/lib/python3.10/site-packages (from panel) (24.2)
# Requirement already satisfied: markdown-it-py in ./prompt-gen-env/lib/python3.10/site-packages (from panel) (3.0.0)
# Requirement already satisfied: mdit-py-plugins in ./prompt-gen-env/lib/python3.10/site-packages (from panel) (0.4.2)
# Requirement already satisfied: pyviz-comms>=2.0.0 in ./prompt-gen-env/lib/python3.10/site-packages (from panel) (3.0.4)
# Requirement already satisfied: requests in ./prompt-gen-env/lib/python3.10/site-packages (from panel) (2.32.3)
# Requirement already satisfied: pandas>=1.2 in ./prompt-gen-env/lib/python3.10/site-packages (from panel) (2.2.3)
# Requirement already satisfied: bleach in ./prompt-gen-env/lib/python3.10/site-packages (from panel) (6.2.0)
# Requirement already satisfied: tqdm in ./prompt-gen-env/lib/python3.10/site-packages (from panel) (4.67.1)
# Requirement already satisfied: linkify-it-py in ./prompt-gen-env/lib/python3.10/site-packages (from panel) (2.0.3)
# Requirement already satisfied: typing-extensions in ./prompt-gen-env/lib/python3.10/site-packages (from panel) (4.13.2)
# Requirement already satisfied: bokeh<3.8.0,>=3.5.0 in ./prompt-gen-env/lib/python3.10/site-packages (from panel) (3.7.2)
# Requirement already satisfied: markdown in ./prompt-gen-env/lib/python3.10/site-packages (from panel) (3.8)
# Requirement already satisfied: ipywidgets==8.* in ./prompt-gen-env/lib/python3.10/site-packages (from jupyter_bokeh) (8.1.6)
# Requirement already satisfied: pillow>=7.1.0 in ./prompt-gen-env/lib/python3.10/site-packages (from bokeh<3.8.0,>=3.5.0->panel) (11.2.1)
# Requirement already satisfied: PyYAML>=3.10 in ./prompt-gen-env/lib/python3.10/site-packages (from bokeh<3.8.0,>=3.5.0->panel) (6.0.2)
# Requirement already satisfied: numpy>=1.16 in ./prompt-gen-env/lib/python3.10/site-packages (from bokeh<3.8.0,>=3.5.0->panel) (2.2.5)
# Requirement already satisfied: narwhals>=1.13 in ./prompt-gen-env/lib/python3.10/site-packages (from bokeh<3.8.0,>=3.5.0->panel) (1.37.0)
# Requirement already satisfied: xyzservices>=2021.09.1 in ./prompt-gen-env/lib/python3.10/site-packages (from bokeh<3.8.0,>=3.5.0->panel) (2025.4.0)
# Requirement already satisfied: tornado>=6.2 in ./prompt-gen-env/lib/python3.10/site-packages (from bokeh<3.8.0,>=3.5.0->panel) (6.4.2)
# Requirement already satisfied: Jinja2>=2.9 in ./prompt-gen-env/lib/python3.10/site-packages (from bokeh<3.8.0,>=3.5.0->panel) (3.1.6)
# Requirement already satisfied: contourpy>=1.2 in ./prompt-gen-env/lib/python3.10/site-packages (from bokeh<3.8.0,>=3.5.0->panel) (1.3.2)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in ./prompt-gen-env/lib/python3.10/site-packages (from ipywidgets==8.*->jupyter_bokeh) (4.0.14)
# Requirement already satisfied: comm>=0.1.3 in ./prompt-gen-env/lib/python3.10/site-packages (from ipywidgets==8.*->jupyter_bokeh) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in ./prompt-gen-env/lib/python3.10/site-packages (from ipywidgets==8.*->jupyter_bokeh) (8.36.0)
# Requirement already satisfied: traitlets>=4.3.1 in ./prompt-gen-env/lib/python3.10/site-packages (from ipywidgets==8.*->jupyter_bokeh) (5.14.3)
# Requirement already satisfied: jupyterlab_widgets~=3.0.14 in ./prompt-gen-env/lib/python3.10/site-packages (from ipywidgets==8.*->jupyter_bokeh) (3.0.14)
# Requirement already satisfied: tzdata>=2022.7 in ./prompt-gen-env/lib/python3.10/site-packages (from pandas>=1.2->panel) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in ./prompt-gen-env/lib/python3.10/site-packages (from pandas>=1.2->panel) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./prompt-gen-env/lib/python3.10/site-packages (from pandas>=1.2->panel) (2.9.0.post0)
# Requirement already satisfied: webencodings in ./prompt-gen-env/lib/python3.10/site-packages (from bleach->panel) (0.5.1)
# Requirement already satisfied: uc-micro-py in ./prompt-gen-env/lib/python3.10/site-packages (from linkify-it-py->panel) (1.0.3)
# Requirement already satisfied: mdurl~=0.1 in ./prompt-gen-env/lib/python3.10/site-packages (from markdown-it-py->panel) (0.1.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./prompt-gen-env/lib/python3.10/site-packages (from requests->panel) (2.4.0)
# Requirement already satisfied: idna<4,>=2.5 in ./prompt-gen-env/lib/python3.10/site-packages (from requests->panel) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in ./prompt-gen-env/lib/python3.10/site-packages (from requests->panel) (2025.4.26)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./prompt-gen-env/lib/python3.10/site-packages (from requests->panel) (3.4.1)
# Requirement already satisfied: pexpect>4.3 in ./prompt-gen-env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (4.9.0)
# Requirement already satisfied: decorator in ./prompt-gen-env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (5.2.1)
# Requirement already satisfied: exceptiongroup in ./prompt-gen-env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (1.2.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in ./prompt-gen-env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (3.0.51)
# Requirement already satisfied: jedi>=0.16 in ./prompt-gen-env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.19.2)
# Requirement already satisfied: stack_data in ./prompt-gen-env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.6.3)
# Requirement already satisfied: matplotlib-inline in ./prompt-gen-env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.1.7)
# Requirement already satisfied: pygments>=2.4.0 in ./prompt-gen-env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (2.19.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./prompt-gen-env/lib/python3.10/site-packages (from Jinja2>=2.9->bokeh<3.8.0,>=3.5.0->panel) (3.0.2)
# Requirement already satisfied: six>=1.5 in ./prompt-gen-env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.2->panel) (1.17.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./prompt-gen-env/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in ./prompt-gen-env/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.7.0)
# Requirement already satisfied: wcwidth in ./prompt-gen-env/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.2.13)
# Requirement already satisfied: asttokens>=2.1.0 in ./prompt-gen-env/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (3.0.0)
# Requirement already satisfied: executing>=1.2.0 in ./prompt-gen-env/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (2.2.0)
# Requirement already satisfied: pure-eval in ./prompt-gen-env/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.2.3)

# %%
from langchain_community.document_loaders.csv_loader import CSVLoader
from langchain_community.vectorstores import FAISS
from langchain_community.docstore.in_memory import InMemoryDocstore
# from langchain.embeddings import HuggingFaceEmbeddings
from langchain_huggingface import HuggingFaceEmbeddings
from langchain.llms import CTransformers
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import ChatPromptTemplate
import pandas as pd
import faiss

# %%
import panel as pn
pn.extension()

# Set default styles for better appearance
pn.config.sizing_mode = "stretch_width"

# Dropdown for file selection - made wider
file_dropdown = pn.widgets.Select(
    name='Datei auswählen',
    options=[
        'elektromotoren-100.csv',
        'customers-100.csv'
    ],
    width=600  # Increased width
)

# Text display of selection
selected_file_display = pn.pane.Str(
    '', 
    styles={'font-size': '16px', 'color': 'green'},
    width=600  # Match width with dropdown
)

# Text input with conditional default - made wider
text_input = pn.widgets.TextInput(
    name='Suchanfrage',
    placeholder='Geben Sie Ihre Suchanfrage ein',
    width=600  # Same width as other components
)

# Callback function for selection changes
def update_display(event):
    selected_file_display.object = f"Ausgewählte Datei: {event.new}"
    
    # Update text input based on selection
    if event.new == 'elektromotoren-100.csv':
        text_input.value = 'Wann wurde der Motor mit Config ID CFG345 eingebaut?'
    else:
        text_input.value = 'Which company does Sheryl Baxter work for?'

file_dropdown.param.watch(update_display, 'value')

# Initialize with default value
if file_dropdown.value == 'elektromotoren-100.csv':
    text_input.value = 'Wann wurde der Motor mit Config ID CFG345 eingebaut?'
else:
    text_input.value = 'Which company does Sheryl Baxter work for?'

# Create layout with some additional styling
layout = pn.Column(
    pn.Row(file_dropdown, margin=(0, 0, 20, 0)),
    pn.Row(selected_file_display, margin=(0, 0, 20, 0)),
    pn.Row(text_input),
    width=650,  # Container width
    margin=(20, 20, 20, 20)  # Add some margin around the container
)

# Display
layout.servable()
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='2193c1c5-6ad7-4a4f-b76e-29c637a45406'>
#   <div id="e1a5eab8-7399-47cf-a378-bd138a048cae" data-root-id="2193c1c5-6ad7-4a4f-b76e-29c637a45406" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"bedde690-55ea-4bff-86ac-c72b1b497337":{"version":"3.7.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"2193c1c5-6ad7-4a4f-b76e-29c637a45406"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"ca0ac1eb-3f74-4feb-810d-f3cad6090577","attributes":{"plot_id":"2193c1c5-6ad7-4a4f-b76e-29c637a45406","comm_id":"df6a80aced064abd9db53c917fc49ce6","client_comm_id":"59116cf6d30147d988053d99e81b2849"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1" ...
#   var render_items = [{"docid":"bedde690-55ea-4bff-86ac-c72b1b497337","roots":{"2193c1c5-6ad7-4a4f-b76e-29c637a45406":"e1a5eab8-7399-47cf-a378-bd138a048cae"},"root_ids":["2193c1c5-6ad7-4a4f-b76e-29c637a45406"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# BokehModel(combine_events=True, render_bundle={'docs_json': {'bab38baf-5771-4396-b10d-780785327128': {'version…

# %%
file_path = file_dropdown.value
question = text_input.value
data = pd.read_csv(file_path)
data.head()

# Load documents
loader = CSVLoader(file_path=file_path)
docs = loader.load_and_split()

# Use BGE Embeddings
if file_path == "elektromotoren-100.csv":
    embedding_model_name = "BAAI/bge-m3" # mulitlingual
else:
    embedding_model_name = "BAAI/bge-base-en"
embeddings = HuggingFaceEmbeddings(model_name=embedding_model_name)

# Create FAISS index
dim = len(embeddings.embed_query("Hello world"))
index = faiss.IndexFlatL2(dim)
vector_store = FAISS(
    embedding_function=embeddings,
    index=index,
    docstore=InMemoryDocstore(),
    index_to_docstore_id={}
)
vector_store.add_documents(documents=docs)
doc_id = list(vector_store.docstore._dict.keys())[0]
print(doc_id)
print(vector_store.docstore._dict[doc_id].page_content)

# ---- STEP 1: Set up the prompt template ----
if file_path == "elektromotoren-100.csv":
    system_prompt = (
        "Du bist ein Assistent zur Analyse und Auswertung von Daten zu Elektromotoren. "
        "Nutze die folgenden Teile des abgerufenen Tracing-Datensatzes, um die gestellte "
        "Frage zu beantworten. Wenn du die Antwort nicht sicher weißt, gib an, dass du es "
        "nicht weißt. Antworte in maximal drei Sätzen und halte die Antwort präzise und sachlich."
        "\n\n"
        "{context}"
    )


    prompt = ChatPromptTemplate.from_messages([
        ("system", system_prompt),
        ("human", "{input}"),
    ])
else:
    system_prompt = (
        "You are an assistant for question-answering tasks. "
        "Use the following pieces of retrieved context to answer "
        "the question. If you don't know the answer, say that you "
        "don't know. Use three sentences maximum and keep the "
        "answer concise."
        "\n\n"
        "{context}"
    )

    prompt = ChatPromptTemplate.from_messages([
        ("system", system_prompt),
        ("human", "{input}"),
    ])

# ---- STEP 2: Retrieve documents according to question ----
retriever = vector_store.as_retriever()
docs = retriever.invoke(question)

# ---- STEP 3: Fill the prompt ----
filled_prompt = prompt.format(
    context="\n\n".join([doc.page_content for doc in docs]),
    input=question
)

print(filled_prompt)
# Out:
# 2f2ab5f7-d7ff-4bbd-a8dd-d5d9bbcb4cd2
# Index: 1
# Motor_ID: EM2025000
# Config_ID: CFG345
# Spannung_V: 400
# Leistung_kW: 44.6
# Drehmoment_Nm: 39.2
# Temp_Bereich_C: -25 – 118
# Einbaudatum: 2024-07-06
# Qualitaetsprüfung: nein
# Fertigungsstraße: Linie C
# System: Du bist ein Assistent zur Analyse und Auswertung von Daten zu Elektromotoren. Nutze die folgenden Teile des abgerufenen Tracing-Datensatzes, um die gestellte Frage zu beantworten. Wenn du die Antwort nicht sicher weißt, gib an, dass du es nicht weißt. Antworte in maximal drei Sätzen und halte die Antwort präzise und sachlich.
#
# Index: 20
# Motor_ID: EM2025019
# Config_ID: CFG825
# Spannung_V: 480
# Leistung_kW: 1.8
# Drehmoment_Nm: 37.4
# Temp_Bereich_C: -3 – 91
# Einbaudatum: 2024-07-19
# Qualitaetsprüfung: nein
# Fertigungsstraße: Linie B
#
# Index: 25
# Motor_ID: EM2025024
# Config_ID: CFG718
# Spannung_V: 480
# Leistung_kW: 30.7
# Drehmoment_Nm: 376.9
# Temp_Bereich_C: -30 – 95
# Einbaudatum: 2025-03-30
# Qualitaetsprüfung: nein
# Fertigungsstraße: Linie B
#
# Index: 58
# Motor_ID: EM2025057
# Config_ID: CFG500
# Spannung_V: 480
# Leistung_kW: 45.1
# Drehmoment_Nm: 104.6
# Temp_Bereich_C: -25 – 89
# Einbaudatum: 2024-03-21
# Qualitaetsprüfung: nein
# Fertigungsstraße: Linie C
#
# Index: 28
# Motor_ID: EM2025027
# Config_ID: CFG100
# Spannung_V: 400
# Leistung_kW: 25.2
# Drehmoment_Nm: 375.1
# Temp_Bereich_C: 0 – 123
# Einbaudatum: 2023-06-06
# Qualitaetsprüfung: ja
# Fertigungsstraße: Linie A
# Human: Wann wurde der Motor mit Config ID CFG825 eingebaut?

# %% [markdown]
# # Same Code as in cell above but step by step

# %%
file_path = file_dropdown.value
question = text_input.value
print(file_path)
print(question)
data = pd.read_csv(file_path)
data.head()
# Out:
# customers-100.csv
# Which company does Sheryl Baxter work for?
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# 3          Dominican Republic  001-808-617-6467x12895        +1-813-324-8756
# 4  Slovakia (Slovak Republic)  001-234-203-0635x76146  001-199-446-3860x3486
#
#                          Email Subscription Date                      Website
# 0     zunigavanessa@smith.info        2020-08-24   http://www.stephenson.com/
# 1              vmata@colon.com        2021-04-23        http://www.hobbs.com/
# 2          beckycarr@hogan.com        2020-03-25     http://www.lawrence.com/
# 3  stanleyblackwell@benson.org        2020-06-02   http://www.good-lyons.com/
# 4      colinalvarado@miles.net        2021-04-17  https://goodwin-ingram.com/

# %%
# Load documents
loader = CSVLoader(file_path=file_path)
docs = loader.load_and_split()
docs[0:3]
# Out:
# [Document(metadata={'source': 'customers-100.csv', 'row': 0}, page_content='Index: 1\nCustomer Id: DD37Cf93aecA6Dc\nFirst Name: Sheryl\nLast Name: Baxter\nCompany: Rasmussen Group\nCity: East Leonard\nCountry: Chile\nPhone 1: 229.077.5154\nPhone 2: 397.884.0519x718\nEmail: zunigavanessa@smith.info\nSubscription Date: 2020-08-24\nWebsite: http://www.stephenson.com/'),
#  Document(metadata={'source': 'customers-100.csv', 'row': 1}, page_content='Index: 2\nCustomer Id: 1Ef7b82A4CAAD10\nFirst Name: Preston\nLast Name: Lozano\nCompany: Vega-Gentry\nCity: East Jimmychester\nCountry: Djibouti\nPhone 1: 5153435776\nPhone 2: 686-620-1820x944\nEmail: vmata@colon.com\nSubscription Date: 2021-04-23\nWebsite: http://www.hobbs.com/'),
#  Document(metadata={'source': 'customers-100.csv', 'row': 2}, page_content='Index: 3\nCustomer Id: 6F94879bDAfE5a6\nFirst Name: Roy\nLast Name: Berry\nCompany: Murillo-Perry\nCity: Isabelborough\nCountry: Antigua and Barbuda\nPhone 1: +1-539-402-0259\nPhone 2: (496)978-3969x58947\nEmail: beckycarr@hogan.com\nSubscription Date: 2020-03-25\nWebsite: http://www.lawrence.com/')]

# %%
# Use BGE Embeddings
if file_path == "elektromotoren-100.csv":
    embedding_model_name = "BAAI/bge-m3" # mulitlingual
else:
    embedding_model_name = "BAAI/bge-base-en"
embeddings = HuggingFaceEmbeddings(model_name=embedding_model_name)

# %%
# Create FAISS index
dim = len(embeddings.embed_query("Hello world"))
print("embeddings dimension:", dim)
index = faiss.IndexFlatL2(dim)
vector_store = FAISS(
    embedding_function=embeddings,
    index=index,
    docstore=InMemoryDocstore(),
    index_to_docstore_id={}
)
# Out:
# embeddings dimension: 768

# %%
vector_store.add_documents(documents=docs)
doc_id = list(vector_store.docstore._dict.keys())[0]
print(doc_id)
print(vector_store.docstore._dict[doc_id].page_content)
# Out:
# b653e141-07d4-4cea-b165-4348c1008b0f
# Index: 1
# Customer Id: DD37Cf93aecA6Dc
# First Name: Sheryl
# Last Name: Baxter
# Company: Rasmussen Group
# City: East Leonard
# Country: Chile
# Phone 1: 229.077.5154
# Phone 2: 397.884.0519x718
# Email: zunigavanessa@smith.info
# Subscription Date: 2020-08-24
# Website: http://www.stephenson.com/

# %%
# # Use Mistral 7B via ctransformers
# llm = CTransformers(
#     model='TheBloke/Mistral-7B-Instruct-v0.1-GGUF',  # GGUF quantized
#     # model_file='mistral-7b-instruct-v0.1.Q4_K_M.gguf',
#     config={'max_new_tokens': 10000, 'temperature': 0.7}
# )

# %%
# ---- STEP 1: Set up the prompt template ----
if file_path == "elektromotoren-100.csv":
    system_prompt = (
        "Du bist ein Assistent zur Analyse und Auswertung von Daten zu Elektromotoren. "
        "Nutze die folgenden Teile des abgerufenen Tracing-Datensatzes, um die gestellte "
        "Frage zu beantworten. Wenn du die Antwort nicht sicher weißt, gib an, dass du es "
        "nicht weißt. Antworte in maximal drei Sätzen und halte die Antwort präzise und sachlich."
        "\n\n"
        "{context}"
    )


    prompt = ChatPromptTemplate.from_messages([
        ("system", system_prompt),
        ("human", "{input}"),
    ])
    
    # question = "Wann wurde der Motor mit Config ID CFG345 eingebaut?"
else:
    system_prompt = (
        "You are an assistant for question-answering tasks. "
        "Use the following pieces of retrieved context to answer "
        "the question. If you don't know the answer, say that you "
        "don't know. Use three sentences maximum and keep the "
        "answer concise."
        "\n\n"
        "{context}"
    )

    prompt = ChatPromptTemplate.from_messages([
        ("system", system_prompt),
        ("human", "{input}"),
    ])


    # question = "which company does Sheryl Baxter work for?"

# ---- STEP 2: Retrieve documents according to question ----
retriever = vector_store.as_retriever()
docs = retriever.invoke(question)

# # ---- STEP 3: Preview the retrieved context ----
# print("Retrieved documents:\n")
# for i, doc in enumerate(docs):
#     print(f"[{i+1}] {doc.page_content}\n")

# ---- STEP 4: Fill the prompt manually ----
filled_prompt = prompt.format(
    context="\n\n".join([doc.page_content for doc in docs]),
    input=question
)

print("\n\n==== Final Prompt Sent to the LLM ====\n")
print(filled_prompt)

# # ---- STEP 5: Run the LLM with the filled prompt ----

# response = llm.invoke(filled_prompt)
# print("\n\n==== LLM Answer ====\n")
# print(response)
# Out:
# ==== Final Prompt Sent to the LLM ====
#
# System: You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, say that you don't know. Use three sentences maximum and keep the answer concise.
#
# Index: 1
# Customer Id: DD37Cf93aecA6Dc
# First Name: Sheryl
# Last Name: Baxter
# Company: Rasmussen Group
# City: East Leonard
# Country: Chile
# Phone 1: 229.077.5154
# Phone 2: 397.884.0519x718
# Email: zunigavanessa@smith.info
# Subscription Date: 2020-08-24
# Website: http://www.stephenson.com/
#
# Index: 9
# Customer Id: C2dE4dEEc489ae0
# First Name: Sheryl
# Last Name: Meyers
# Company: Browning-Simon
# City: Robersonstad
# Country: Cyprus
# Phone 1: 854-138-4911x5772
# Phone 2: +1-448-910-2276x729
# Email: mariokhan@ryan-pope.org
# Subscription Date: 2020-01-13
# Website: https://www.bullock.net/
#
# Index: 70
# Customer Id: CC68FD1D3Bbbf22
# First Name: Riley
# Last Name: Good
# Company: Wade PLC
# City: Erikaville
# Country: Canada
# Phone 1: 6977745822
# Phone 2: 855-436-7641
# Email: alex06@galloway.com
# Subscription Date: 2020-02-03
# Website: http://conway.org/
#
# Index: 77
# Customer Id: BF6a1f9bd1bf8DE
# First Name: Brittany
# Last Name: Zuniga
# Company: Mason-Hester
# City: West Reginald
# Country: Kyrgyz Republic
# Phone 1: (050)136-9025
# Phone 2: 001-480-851-2496x0157
# Email: mchandler@cochran-huerta.org
# Subscription Date: 2021-07-24
# Website: http://www.boyle.com/
# Human: Which company does Sheryl Baxter work for?
